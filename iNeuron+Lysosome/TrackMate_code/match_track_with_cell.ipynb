# %%
from os import path
import numpy as np
import pandas as pd
import natsort
import glob
import cv2
import os
import tifffile as tiff
import imageio
import matplotlib.pyplot as plt
from skimage.transform import resize
from skimage import exposure
import scipy.io
import anndata
from skimage.transform import warp
from skimage.draw import polygon
from PIL import Image
import seaborn as sns
import dask.array as da
import imagecodecs
import math
import skimage
from skimage import transform
import scanpy as sc
from scipy.sparse import issparse
from scipy.stats import linregress

# %% [markdown]
# # Load Xenium Result

# %%
adata_xenium = sc.read_10x_h5(
    filename="path/to/file/cell_feature_matrix.h5"
)
stitched_image = np.load('stitched_images_BFP/stitched_BFP.npy')

# %%
csv_file_path = 'path/to/file/cell_boundaries.csv.gz'
cell_boundaries_csv = pd.read_csv(csv_file_path)

cell_boundaries_csv['vertex_x_coord'] = cell_boundaries_csv['vertex_x']/0.2125
cell_boundaries_csv['vertex_y_coord'] = cell_boundaries_csv['vertex_y']/0.2125

affine_matrix = np.loadtxt('path/to/file/matrix.csv', delimiter=',')
affine_matrix_inv = np.linalg.inv(affine_matrix)

homogeneous_coordinates = np.hstack([cell_boundaries_csv[['vertex_x_coord', 'vertex_y_coord']].values, 
                                     np.ones((cell_boundaries_csv.shape[0], 1))])
transformed_coordinates = homogeneous_coordinates.dot(affine_matrix_inv.T)
cell_boundaries_csv['x_transformed'] = transformed_coordinates[:, 0]
cell_boundaries_csv['y_transformed'] = transformed_coordinates[:, 1]

cell_boundaries_csv['x_transformed'] = round(cell_boundaries_csv['x_transformed']).astype(int)
cell_boundaries_csv['y_transformed'] = round(cell_boundaries_csv['y_transformed']).astype(int)

# %%
cell_boundaries_csv_agg = cell_boundaries_csv.groupby('cell_id').agg({
    'x_transformed': ['min', 'max'],
    'y_transformed': ['min', 'max']
})
cell_boundaries_csv_agg.columns = ['_'.join(c) for c in cell_boundaries_csv_agg.columns]

# %%
valid_ids = cell_boundaries_csv_agg[
    (cell_boundaries_csv_agg['x_transformed_min'] >= 0) &
    (cell_boundaries_csv_agg['x_transformed_max'] < stitched_image.shape[1]) &
    (cell_boundaries_csv_agg['y_transformed_min'] >= 0) &
    (cell_boundaries_csv_agg['y_transformed_max'] < stitched_image.shape[0])
].index

cell_boundaries_csv = cell_boundaries_csv[cell_boundaries_csv['cell_id'].isin(valid_ids)]

# %% [markdown]
# # Run for all FOVs

# %%
for FOV_num in range(1, 465):
    if FOV_num % 15 == 0:
        continue
    num_of_row = FOV_num // 15 + 1
    num_of_col = FOV_num % 15
    y_sub = int((num_of_row - 1) * 2000 * 0.98)
    x_sub = int((num_of_col - 1) * 2000 * 0.98)

    df_fov = cell_boundaries_csv.copy()
    df_fov['x_transformed_subed'] = df_fov['x_transformed'] - x_sub
    df_fov['y_transformed_subed'] = df_fov['y_transformed'] - y_sub
    valid_ids = cell_boundaries_csv_agg[
        (cell_boundaries_csv_agg['x_transformed_min'] >= x_sub) &
        (cell_boundaries_csv_agg['x_transformed_max'] < x_sub + 2000) &
        (cell_boundaries_csv_agg['y_transformed_min'] >= y_sub) &
        (cell_boundaries_csv_agg['y_transformed_max'] < y_sub + 2000)
    ].index
    df_fov = df_fov[df_fov['cell_id'].isin(valid_ids)]
    
    field_str = f"{FOV_num:04d}"
    base = f"Field{field_str}_stack"
    results_dir = "TrackMateResults"
    spots_path  = f"{results_dir}/Field{field_str}/{base}-spots.csv"
    tracks_path = f"{results_dir}/Field{field_str}/{base}-tracks.csv"
    spots  = pd.read_csv(spots_path,  header=0, skiprows=[1,2,3], index_col=0)
    tracks = pd.read_csv(tracks_path, header=0, skiprows=[1,2,3], index_col=0)
    
    spots['POSITION_X_p'] = (spots['POSITION_X'] * 100).clip(upper=1999)
    spots['POSITION_Y_p'] = (spots['POSITION_Y'] * 100).clip(upper=1999)
    spots = spots.assign(
        col=spots['POSITION_X_p'].round().astype(int),
        row=spots['POSITION_Y_p'].round().astype(int),
    )
    
    height, width = (2000, 2000)
    df_list = []
    for cell_id, grp in df_fov.groupby('cell_id'):
        xs = grp['x_transformed_subed'].to_numpy()
        ys = grp['y_transformed_subed'].to_numpy()
        cols = np.round(xs).astype(int)
        rows = np.round(ys).astype(int)
        rr, cc = polygon(rows, cols, shape=(height, width))
        df_cell = pd.DataFrame({
            'cell_id': cell_id,
            'row': rr,
            'col': cc,
        })
        df_list.append(df_cell)
    pixels_df = pd.concat(df_list, ignore_index=True)
    
    merged = spots.merge(pixels_df, on=['row','col'], how='left')
    total_pos = spots.groupby('TRACK_ID').size().rename('total_positions')
    in_cell = (
        merged
        .dropna(subset=['cell_id'])
        .groupby(['TRACK_ID','cell_id'])
        .size()
        .rename('positions_in_cell')
    )
    result = (
        in_cell
        .reset_index()
        .merge(total_pos.reset_index(), on='TRACK_ID')
    )
    result = result[
        (result['positions_in_cell'] > 0) &
        (result['positions_in_cell'] < result['total_positions'])
    ].reset_index(drop=True)
    
    merged_result = result.merge(tracks, how='left', on='TRACK_ID')
    merged_result = merged_result[merged_result['TRACK_DISPLACEMENT'] > 0.05]
    merged_result['FOV'] = FOV_num
    
    out_path = (
        "Track_Cell_Result"
        f"/Field{field_str}_track_cell.csv"
    )
    merged_result.to_csv(out_path, index=False)
    print(f"Finished FOV {FOV_num} → wrote {out_path}")
# Out:
# Finished FOV 1 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0001_track_cell.csv
# Finished FOV 2 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0002_track_cell.csv
# Finished FOV 3 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0003_track_cell.csv
# Finished FOV 4 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0004_track_cell.csv
# Finished FOV 5 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0005_track_cell.csv
# Finished FOV 6 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0006_track_cell.csv
# Finished FOV 7 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0007_track_cell.csv
# Finished FOV 8 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0008_track_cell.csv
# Finished FOV 9 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0009_track_cell.csv
# Finished FOV 10 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0010_track_cell.csv
# Finished FOV 11 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0011_track_cell.csv
# Finished FOV 12 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0012_track_cell.csv
# Finished FOV 13 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0013_track_cell.csv
# Finished FOV 14 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0014_track_cell.csv
# Finished FOV 16 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0016_track_cell.csv
# Finished FOV 17 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0017_track_cell.csv
# Finished FOV 18 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0018_track_cell.csv
# Finished FOV 19 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0019_track_cell.csv
# Finished FOV 20 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0020_track_cell.csv
# Finished FOV 21 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0021_track_cell.csv
# Finished FOV 22 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0022_track_cell.csv
# Finished FOV 23 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0023_track_cell.csv
# Finished FOV 24 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0024_track_cell.csv
# Finished FOV 25 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0025_track_cell.csv
# Finished FOV 26 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0026_track_cell.csv
# Finished FOV 27 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0027_track_cell.csv
# Finished FOV 28 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0028_track_cell.csv
# Finished FOV 29 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0029_track_cell.csv
# Finished FOV 31 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0031_track_cell.csv
# Finished FOV 32 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0032_track_cell.csv
# Finished FOV 33 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0033_track_cell.csv
# Finished FOV 34 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0034_track_cell.csv
# Finished FOV 35 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0035_track_cell.csv
# Finished FOV 36 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0036_track_cell.csv
# Finished FOV 37 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0037_track_cell.csv
# Finished FOV 38 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0038_track_cell.csv
# Finished FOV 39 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0039_track_cell.csv
# Finished FOV 40 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0040_track_cell.csv
# Finished FOV 41 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0041_track_cell.csv
# Finished FOV 42 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0042_track_cell.csv
# Finished FOV 43 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0043_track_cell.csv
# Finished FOV 44 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0044_track_cell.csv
# Finished FOV 46 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0046_track_cell.csv
# Finished FOV 47 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0047_track_cell.csv
# Finished FOV 48 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0048_track_cell.csv
# Finished FOV 49 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0049_track_cell.csv
# Finished FOV 50 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0050_track_cell.csv
# Finished FOV 51 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0051_track_cell.csv
# Finished FOV 52 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0052_track_cell.csv
# Finished FOV 53 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0053_track_cell.csv
# Finished FOV 54 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0054_track_cell.csv
# Finished FOV 55 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0055_track_cell.csv
# Finished FOV 56 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0056_track_cell.csv
# Finished FOV 57 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0057_track_cell.csv
# Finished FOV 58 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0058_track_cell.csv
# Finished FOV 59 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0059_track_cell.csv
# Finished FOV 61 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0061_track_cell.csv
# Finished FOV 62 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0062_track_cell.csv
# Finished FOV 63 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0063_track_cell.csv
# Finished FOV 64 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0064_track_cell.csv
# Finished FOV 65 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0065_track_cell.csv
# Finished FOV 66 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0066_track_cell.csv
# Finished FOV 67 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0067_track_cell.csv
# Finished FOV 68 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0068_track_cell.csv
# Finished FOV 69 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0069_track_cell.csv
# Finished FOV 70 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0070_track_cell.csv
# Finished FOV 71 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0071_track_cell.csv
# Finished FOV 72 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0072_track_cell.csv
# Finished FOV 73 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0073_track_cell.csv
# Finished FOV 74 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0074_track_cell.csv
# Finished FOV 76 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0076_track_cell.csv
# Finished FOV 77 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0077_track_cell.csv
# Finished FOV 78 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0078_track_cell.csv
# Finished FOV 79 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0079_track_cell.csv
# Finished FOV 80 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0080_track_cell.csv
# Finished FOV 81 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0081_track_cell.csv
# Finished FOV 82 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0082_track_cell.csv
# Finished FOV 83 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0083_track_cell.csv
# Finished FOV 84 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0084_track_cell.csv
# Finished FOV 85 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0085_track_cell.csv
# Finished FOV 86 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0086_track_cell.csv
# Finished FOV 87 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0087_track_cell.csv
# Finished FOV 88 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0088_track_cell.csv
# Finished FOV 89 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0089_track_cell.csv
# Finished FOV 91 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0091_track_cell.csv
# Finished FOV 92 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0092_track_cell.csv
# Finished FOV 93 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0093_track_cell.csv
# Finished FOV 94 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0094_track_cell.csv
# Finished FOV 95 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0095_track_cell.csv
# Finished FOV 96 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0096_track_cell.csv
# Finished FOV 97 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0097_track_cell.csv
# Finished FOV 98 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0098_track_cell.csv
# Finished FOV 99 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0099_track_cell.csv
# Finished FOV 100 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0100_track_cell.csv
# Finished FOV 101 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0101_track_cell.csv
# Finished FOV 102 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0102_track_cell.csv
# Finished FOV 103 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0103_track_cell.csv
# Finished FOV 104 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0104_track_cell.csv
# Finished FOV 106 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0106_track_cell.csv
# Finished FOV 107 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0107_track_cell.csv
# Finished FOV 108 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0108_track_cell.csv
# Finished FOV 109 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0109_track_cell.csv
# Finished FOV 110 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0110_track_cell.csv
# Finished FOV 111 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0111_track_cell.csv
# Finished FOV 112 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0112_track_cell.csv
# Finished FOV 113 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0113_track_cell.csv
# Finished FOV 114 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0114_track_cell.csv
# Finished FOV 115 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0115_track_cell.csv
# Finished FOV 116 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0116_track_cell.csv
# Finished FOV 117 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0117_track_cell.csv
# Finished FOV 118 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0118_track_cell.csv
# Finished FOV 119 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0119_track_cell.csv
# Finished FOV 121 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0121_track_cell.csv
# Finished FOV 122 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0122_track_cell.csv
# Finished FOV 123 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0123_track_cell.csv
# Finished FOV 124 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0124_track_cell.csv
# Finished FOV 125 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0125_track_cell.csv
# Finished FOV 126 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0126_track_cell.csv
# Finished FOV 127 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0127_track_cell.csv
# Finished FOV 128 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0128_track_cell.csv
# Finished FOV 129 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0129_track_cell.csv
# Finished FOV 130 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0130_track_cell.csv
# Finished FOV 131 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0131_track_cell.csv
# Finished FOV 132 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0132_track_cell.csv
# Finished FOV 133 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0133_track_cell.csv
# Finished FOV 134 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0134_track_cell.csv
# Finished FOV 136 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0136_track_cell.csv
# Finished FOV 137 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0137_track_cell.csv
# Finished FOV 138 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0138_track_cell.csv
# Finished FOV 139 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0139_track_cell.csv
# Finished FOV 140 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0140_track_cell.csv
# Finished FOV 141 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0141_track_cell.csv
# Finished FOV 142 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0142_track_cell.csv
# Finished FOV 143 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0143_track_cell.csv
# Finished FOV 144 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0144_track_cell.csv
# Finished FOV 145 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0145_track_cell.csv
# Finished FOV 146 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0146_track_cell.csv
# Finished FOV 147 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0147_track_cell.csv
# Finished FOV 148 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0148_track_cell.csv
# Finished FOV 149 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0149_track_cell.csv
# Finished FOV 151 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0151_track_cell.csv
# Finished FOV 152 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0152_track_cell.csv
# Finished FOV 153 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0153_track_cell.csv
# Finished FOV 154 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0154_track_cell.csv
# Finished FOV 155 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0155_track_cell.csv
# Finished FOV 156 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0156_track_cell.csv
# Finished FOV 157 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0157_track_cell.csv
# Finished FOV 158 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0158_track_cell.csv
# Finished FOV 159 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0159_track_cell.csv
# Finished FOV 160 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0160_track_cell.csv
# Finished FOV 161 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0161_track_cell.csv
# Finished FOV 162 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0162_track_cell.csv
# Finished FOV 163 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0163_track_cell.csv
# Finished FOV 164 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0164_track_cell.csv
# Finished FOV 166 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0166_track_cell.csv
# Finished FOV 167 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0167_track_cell.csv
# Finished FOV 168 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0168_track_cell.csv
# Finished FOV 169 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0169_track_cell.csv
# Finished FOV 170 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0170_track_cell.csv
# Finished FOV 171 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0171_track_cell.csv
# Finished FOV 172 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0172_track_cell.csv
# Finished FOV 173 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0173_track_cell.csv
# Finished FOV 174 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0174_track_cell.csv
# Finished FOV 175 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0175_track_cell.csv
# Finished FOV 176 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0176_track_cell.csv
# Finished FOV 177 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0177_track_cell.csv
# Finished FOV 178 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0178_track_cell.csv
# Finished FOV 179 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0179_track_cell.csv
# Finished FOV 181 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0181_track_cell.csv
# Finished FOV 182 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0182_track_cell.csv
# Finished FOV 183 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0183_track_cell.csv
# Finished FOV 184 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0184_track_cell.csv
# Finished FOV 185 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0185_track_cell.csv
# Finished FOV 186 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0186_track_cell.csv
# Finished FOV 187 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0187_track_cell.csv
# Finished FOV 188 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0188_track_cell.csv
# Finished FOV 189 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0189_track_cell.csv
# Finished FOV 190 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0190_track_cell.csv
# Finished FOV 191 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0191_track_cell.csv
# Finished FOV 192 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0192_track_cell.csv
# Finished FOV 193 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0193_track_cell.csv
# Finished FOV 194 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0194_track_cell.csv
# Finished FOV 196 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0196_track_cell.csv
# Finished FOV 197 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0197_track_cell.csv
# Finished FOV 198 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0198_track_cell.csv
# Finished FOV 199 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0199_track_cell.csv
# Finished FOV 200 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0200_track_cell.csv
# Finished FOV 201 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0201_track_cell.csv
# Finished FOV 202 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0202_track_cell.csv
# Finished FOV 203 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0203_track_cell.csv
# Finished FOV 204 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0204_track_cell.csv
# Finished FOV 205 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0205_track_cell.csv
# Finished FOV 206 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0206_track_cell.csv
# Finished FOV 207 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0207_track_cell.csv
# Finished FOV 208 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0208_track_cell.csv
# Finished FOV 209 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0209_track_cell.csv
# Finished FOV 211 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0211_track_cell.csv
# Finished FOV 212 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0212_track_cell.csv
# Finished FOV 213 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0213_track_cell.csv
# Finished FOV 214 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0214_track_cell.csv
# Finished FOV 215 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0215_track_cell.csv
# Finished FOV 216 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0216_track_cell.csv
# Finished FOV 217 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0217_track_cell.csv
# Finished FOV 218 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0218_track_cell.csv
# Finished FOV 219 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0219_track_cell.csv
# Finished FOV 220 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0220_track_cell.csv
# Finished FOV 221 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0221_track_cell.csv
# Finished FOV 222 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0222_track_cell.csv
# Finished FOV 223 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0223_track_cell.csv
# Finished FOV 224 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0224_track_cell.csv
# Finished FOV 226 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0226_track_cell.csv
# Finished FOV 227 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0227_track_cell.csv
# Finished FOV 228 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0228_track_cell.csv
# Finished FOV 229 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0229_track_cell.csv
# Finished FOV 230 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0230_track_cell.csv
# Finished FOV 231 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0231_track_cell.csv
# Finished FOV 232 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0232_track_cell.csv
# Finished FOV 233 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0233_track_cell.csv
# Finished FOV 234 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0234_track_cell.csv
# Finished FOV 235 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0235_track_cell.csv
# Finished FOV 236 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0236_track_cell.csv
# Finished FOV 237 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0237_track_cell.csv
# Finished FOV 238 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0238_track_cell.csv
# Finished FOV 239 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0239_track_cell.csv
# Finished FOV 241 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0241_track_cell.csv
# Finished FOV 242 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0242_track_cell.csv
# Finished FOV 243 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0243_track_cell.csv
# Finished FOV 244 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0244_track_cell.csv
# Finished FOV 245 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0245_track_cell.csv
# Finished FOV 246 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0246_track_cell.csv
# Finished FOV 247 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0247_track_cell.csv
# Finished FOV 248 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0248_track_cell.csv
# Finished FOV 249 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0249_track_cell.csv
# Finished FOV 250 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0250_track_cell.csv
# Finished FOV 251 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0251_track_cell.csv
# Finished FOV 252 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0252_track_cell.csv
# Finished FOV 253 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0253_track_cell.csv
# Finished FOV 254 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0254_track_cell.csv
# Finished FOV 256 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0256_track_cell.csv
# Finished FOV 257 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0257_track_cell.csv
# Finished FOV 258 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0258_track_cell.csv
# Finished FOV 259 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0259_track_cell.csv
# Finished FOV 260 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0260_track_cell.csv
# Finished FOV 261 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0261_track_cell.csv
# Finished FOV 262 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0262_track_cell.csv
# Finished FOV 263 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0263_track_cell.csv
# Finished FOV 264 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0264_track_cell.csv
# Finished FOV 265 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0265_track_cell.csv
# Finished FOV 266 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0266_track_cell.csv
# Finished FOV 267 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0267_track_cell.csv
# Finished FOV 268 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0268_track_cell.csv
# Finished FOV 269 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0269_track_cell.csv
# Finished FOV 271 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0271_track_cell.csv
# Finished FOV 272 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0272_track_cell.csv
# Finished FOV 273 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0273_track_cell.csv
# Finished FOV 274 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0274_track_cell.csv
# Finished FOV 275 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0275_track_cell.csv
# Finished FOV 276 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0276_track_cell.csv
# Finished FOV 277 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0277_track_cell.csv
# Finished FOV 278 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0278_track_cell.csv
# Finished FOV 279 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0279_track_cell.csv
# Finished FOV 280 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0280_track_cell.csv
# Finished FOV 281 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0281_track_cell.csv
# Finished FOV 282 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0282_track_cell.csv
# Finished FOV 283 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0283_track_cell.csv
# Finished FOV 284 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0284_track_cell.csv
# Finished FOV 286 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0286_track_cell.csv
# Finished FOV 287 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0287_track_cell.csv
# Finished FOV 288 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0288_track_cell.csv
# Finished FOV 289 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0289_track_cell.csv
# Finished FOV 290 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0290_track_cell.csv
# Finished FOV 291 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0291_track_cell.csv
# Finished FOV 292 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0292_track_cell.csv
# Finished FOV 293 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0293_track_cell.csv
# Finished FOV 294 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0294_track_cell.csv
# Finished FOV 295 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0295_track_cell.csv
# Finished FOV 296 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0296_track_cell.csv
# Finished FOV 297 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0297_track_cell.csv
# Finished FOV 298 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0298_track_cell.csv
# Finished FOV 299 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0299_track_cell.csv
# Finished FOV 301 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0301_track_cell.csv
# Finished FOV 302 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0302_track_cell.csv
# Finished FOV 303 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0303_track_cell.csv
# Finished FOV 304 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0304_track_cell.csv
# Finished FOV 305 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0305_track_cell.csv
# Finished FOV 306 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0306_track_cell.csv
# Finished FOV 307 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0307_track_cell.csv
# Finished FOV 308 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0308_track_cell.csv
# Finished FOV 309 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0309_track_cell.csv
# Finished FOV 310 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0310_track_cell.csv
# Finished FOV 311 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0311_track_cell.csv
# Finished FOV 312 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0312_track_cell.csv
# Finished FOV 313 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0313_track_cell.csv
# Finished FOV 314 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0314_track_cell.csv
# Finished FOV 316 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0316_track_cell.csv
# Finished FOV 317 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0317_track_cell.csv
# Finished FOV 318 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0318_track_cell.csv
# Finished FOV 319 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0319_track_cell.csv
# Finished FOV 320 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0320_track_cell.csv
# Finished FOV 321 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0321_track_cell.csv
# Finished FOV 322 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0322_track_cell.csv
# Finished FOV 323 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0323_track_cell.csv
# Finished FOV 324 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0324_track_cell.csv
# Finished FOV 325 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0325_track_cell.csv
# Finished FOV 326 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0326_track_cell.csv
# Finished FOV 327 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0327_track_cell.csv
# Finished FOV 328 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0328_track_cell.csv
# Finished FOV 329 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0329_track_cell.csv
# Finished FOV 331 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0331_track_cell.csv
# Finished FOV 332 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0332_track_cell.csv
# Finished FOV 333 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0333_track_cell.csv
# Finished FOV 334 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0334_track_cell.csv
# Finished FOV 335 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0335_track_cell.csv
# Finished FOV 336 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0336_track_cell.csv
# Finished FOV 337 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0337_track_cell.csv
# Finished FOV 338 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0338_track_cell.csv
# Finished FOV 339 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0339_track_cell.csv
# Finished FOV 340 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0340_track_cell.csv
# Finished FOV 341 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0341_track_cell.csv
# Finished FOV 342 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0342_track_cell.csv
# Finished FOV 343 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0343_track_cell.csv
# Finished FOV 344 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0344_track_cell.csv
# Finished FOV 346 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0346_track_cell.csv
# Finished FOV 347 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0347_track_cell.csv
# Finished FOV 348 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0348_track_cell.csv
# Finished FOV 349 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0349_track_cell.csv
# Finished FOV 350 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0350_track_cell.csv
# Finished FOV 351 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0351_track_cell.csv
# Finished FOV 352 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0352_track_cell.csv
# Finished FOV 353 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0353_track_cell.csv
# Finished FOV 354 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0354_track_cell.csv
# Finished FOV 355 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0355_track_cell.csv
# Finished FOV 356 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0356_track_cell.csv
# Finished FOV 357 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0357_track_cell.csv
# Finished FOV 358 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0358_track_cell.csv
# Finished FOV 359 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0359_track_cell.csv
# Finished FOV 361 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0361_track_cell.csv
# Finished FOV 362 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0362_track_cell.csv
# Finished FOV 363 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0363_track_cell.csv
# Finished FOV 364 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0364_track_cell.csv
# Finished FOV 365 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0365_track_cell.csv
# Finished FOV 366 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0366_track_cell.csv
# Finished FOV 367 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0367_track_cell.csv
# Finished FOV 368 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0368_track_cell.csv
# Finished FOV 369 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0369_track_cell.csv
# Finished FOV 370 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0370_track_cell.csv
# Finished FOV 371 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0371_track_cell.csv
# Finished FOV 372 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0372_track_cell.csv
# Finished FOV 373 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0373_track_cell.csv
# Finished FOV 374 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0374_track_cell.csv
# Finished FOV 376 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0376_track_cell.csv
# Finished FOV 377 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0377_track_cell.csv
# Finished FOV 378 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0378_track_cell.csv
# Finished FOV 379 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0379_track_cell.csv
# Finished FOV 380 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0380_track_cell.csv
# Finished FOV 381 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0381_track_cell.csv
# Finished FOV 382 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0382_track_cell.csv
# Finished FOV 383 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0383_track_cell.csv
# Finished FOV 384 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0384_track_cell.csv
# Finished FOV 385 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0385_track_cell.csv
# Finished FOV 386 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0386_track_cell.csv
# Finished FOV 387 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0387_track_cell.csv
# Finished FOV 388 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0388_track_cell.csv
# Finished FOV 389 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0389_track_cell.csv
# Finished FOV 391 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0391_track_cell.csv
# Finished FOV 392 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0392_track_cell.csv
# Finished FOV 393 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0393_track_cell.csv
# Finished FOV 394 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0394_track_cell.csv
# Finished FOV 395 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0395_track_cell.csv
# Finished FOV 396 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0396_track_cell.csv
# Finished FOV 397 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0397_track_cell.csv
# Finished FOV 398 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0398_track_cell.csv
# Finished FOV 399 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0399_track_cell.csv
# Finished FOV 400 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0400_track_cell.csv
# Finished FOV 401 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0401_track_cell.csv
# Finished FOV 402 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0402_track_cell.csv
# Finished FOV 403 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0403_track_cell.csv
# Finished FOV 404 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0404_track_cell.csv
# Finished FOV 406 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0406_track_cell.csv
# Finished FOV 407 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0407_track_cell.csv
# Finished FOV 408 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0408_track_cell.csv
# Finished FOV 409 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0409_track_cell.csv
# Finished FOV 410 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0410_track_cell.csv
# Finished FOV 411 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0411_track_cell.csv
# Finished FOV 412 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0412_track_cell.csv
# Finished FOV 413 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0413_track_cell.csv
# Finished FOV 414 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0414_track_cell.csv
# Finished FOV 415 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0415_track_cell.csv
# Finished FOV 416 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0416_track_cell.csv
# Finished FOV 417 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0417_track_cell.csv
# Finished FOV 418 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0418_track_cell.csv
# Finished FOV 419 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0419_track_cell.csv
# Finished FOV 421 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0421_track_cell.csv
# Finished FOV 422 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0422_track_cell.csv
# Finished FOV 423 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0423_track_cell.csv
# Finished FOV 424 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0424_track_cell.csv
# Finished FOV 425 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0425_track_cell.csv
# Finished FOV 426 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0426_track_cell.csv
# Finished FOV 427 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0427_track_cell.csv
# Finished FOV 428 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0428_track_cell.csv
# Finished FOV 429 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0429_track_cell.csv
# Finished FOV 430 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0430_track_cell.csv
# Finished FOV 431 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0431_track_cell.csv
# Finished FOV 432 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0432_track_cell.csv
# Finished FOV 433 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0433_track_cell.csv
# Finished FOV 434 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0434_track_cell.csv
# Finished FOV 436 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0436_track_cell.csv
# Finished FOV 437 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0437_track_cell.csv
# Finished FOV 438 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0438_track_cell.csv
# Finished FOV 439 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0439_track_cell.csv
# Finished FOV 440 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0440_track_cell.csv
# Finished FOV 441 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0441_track_cell.csv
# Finished FOV 442 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0442_track_cell.csv
# Finished FOV 443 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0443_track_cell.csv
# Finished FOV 444 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0444_track_cell.csv
# Finished FOV 445 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0445_track_cell.csv
# Finished FOV 446 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0446_track_cell.csv
# Finished FOV 447 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0447_track_cell.csv
# Finished FOV 448 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0448_track_cell.csv
# Finished FOV 449 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0449_track_cell.csv
# Finished FOV 451 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0451_track_cell.csv
# Finished FOV 452 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0452_track_cell.csv
# Finished FOV 453 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0453_track_cell.csv
# Finished FOV 454 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0454_track_cell.csv
# Finished FOV 455 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0455_track_cell.csv
# Finished FOV 456 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0456_track_cell.csv
# Finished FOV 457 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0457_track_cell.csv
# Finished FOV 458 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0458_track_cell.csv
# Finished FOV 459 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0459_track_cell.csv
# Finished FOV 460 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0460_track_cell.csv
# Finished FOV 461 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0461_track_cell.csv
# Finished FOV 462 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0462_track_cell.csv
# Finished FOV 463 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0463_track_cell.csv
# Finished FOV 464 → wrote /scratch/welchjd_root/welchjd2/shared_data/Xenium_0421_Lyso/Track_Cell_Result/Field0464_track_cell.csv

# %% [markdown]
# # Track Cell Analysis (Find the perturbed gene for the 4 example cells)

# %%
folder = "Track_Cell_Result"
all_files = glob.glob(os.path.join(folder, "Field*_track_cell.csv"))
all_files.sort()

df_list = []
for f in all_files:
    df = pd.read_csv(f)
    df_list.append(df)
combined = pd.concat(df_list, ignore_index=True)
combined['positions_out_cell'] = combined['total_positions'] - combined['positions_in_cell']
combined = combined[
    (combined['positions_in_cell'] > 2) &
    (combined['positions_out_cell'] > 2) &
    (combined['total_positions'] > 5)
]
# Out:
# /tmp/ipykernel_1455099/3009959699.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat(df_list, ignore_index=True)

# %%
combined
# Out:
#        TRACK_ID     cell_id positions_in_cell total_positions TRACK_INDEX  \
# 1            39  bmeaflam-1                 9              21          39
# 3            43  bmehfmbl-1                 8              50          43
# 4            43  bmejpdaj-1                42              50          43
# 6            51  bmejpdaj-1                21              40          51
# 7           272  bmejpdaj-1                 5              15         272
# ...         ...         ...               ...             ...         ...
# 261648     4361  gocmnlci-1                 9              14        4361
# 261653     4453  ackoiddm-1                 5              10        4453
# 261654     4453  gmpmgchh-1                 5              10        4453
# 261655     4457  gmpkndjl-1                 8              11        4457
# 261657     4494  godlkcol-1                 4              11        4494
#
#        NUMBER_SPOTS NUMBER_GAPS NUMBER_SPLITS NUMBER_MERGES NUMBER_COMPLEX  \
# 1                21           0             0             0              0
# 3                50           0             0             0              0
# 4                50           0             0             0              0
# 6                40           0             0             0              0
# 7                15           0             0             0              0
# ...             ...         ...           ...           ...            ...
# 261648           14           0             0             0              0
# 261653           10           1             0             0              0
# 261654           10           1             0             0              0
# 261655           11           1             0             0              0
# 261657           11           0             0             0              0
#
#         ... TRACK_STD_SPEED  TRACK_MEAN_QUALITY  TOTAL_DISTANCE_TRAVELED  \
# 1       ...        0.034830          139.588960                 0.390646
# 3       ...        0.008074          139.385289                 0.380153
# 4       ...        0.008074          139.385289                 0.380153
# 6       ...        0.029394          378.429841                 0.683258
# 7       ...        0.026370          197.360077                 0.227862
# ...     ...             ...                 ...                      ...
# 261648  ...        0.031759           52.584036                 0.205440
# 261653  ...        0.019346            6.887331                 0.283934
# 261654  ...        0.019346            6.887331                 0.283934
# 261655  ...        0.043206            9.640182                 0.351290
# 261657  ...        0.008877            6.699116                 0.221085
#
#         MAX_DISTANCE_TRAVELED  CONFINEMENT_RATIO  MEAN_STRAIGHT_LINE_SPEED  \
# 1                    0.157730           0.350778                  0.006851
# 3                    0.183330           0.455376                  0.003533
# 4                    0.183330           0.455376                  0.003533
# 6                    0.304597           0.445801                  0.007810
# 7                    0.171209           0.751369                  0.012229
# ...                       ...                ...                       ...
# 261648               0.129442           0.562164                  0.008884
# 261653               0.088574           0.230739                  0.006551
# 261654               0.088574           0.230739                  0.006551
# 261655               0.219336           0.624372                  0.019940
# 261657               0.052154           0.235901                  0.005215
#
#         LINEARITY_OF_FORWARD_PROGRESSION  MEAN_DIRECTIONAL_CHANGE_RATE  FOV  \
# 1                               0.350778                      1.290110    1
# 3                               0.455376                      1.046658    1
# 4                               0.455376                      1.046658    1
# 6                               0.445801                      1.858211    1
# 7                               0.751369                      1.561646    1
# ...                                  ...                           ...  ...
# 261648                          0.562164                      1.762969  464
# 261653                          0.222528                      1.402091  464
# 261654                          0.222528                      1.402091  464
# 261655                          0.571013                      1.486425  464
# 261657                          0.235901                      1.591976  464
#
#         positions_out_cell
# 1                       12
# 3                       42
# 4                        8
# 6                       19
# 7                       10
# ...                    ...
# 261648                   5
# 261653                   5
# 261654                   5
# 261655                   3
# 261657                   7
#
# [156826 rows x 32 columns]

# %%
#combined.to_csv("combined_tracks_and_cells.csv",index=False)

# %%
adata_xenium.obs['total_counts'] = (
        adata_xenium.X.sum(axis=1).A1
        if hasattr(adata_xenium.X, "A1")
        else adata_xenium.X.sum(axis=1)
    )
adata_xenium.obs['total_counts'] = adata_xenium.X.sum(axis=1).A1
num_cells_800 = (adata_xenium.obs['total_counts'] >= 800).sum()
adata_filtered = adata_xenium[adata_xenium.obs['total_counts'] >= 800].copy()
sgRNA_genes = [gene for gene in adata_filtered.var_names if '-' in gene and not 'HLA' in gene]
sgRNA_to_target = {sg: sg.split('-')[0] for sg in sgRNA_genes}

idxs = [adata_filtered.var_names.get_loc(g) for g in sgRNA_genes]
mat = adata_filtered.X[:, idxs]
if issparse(mat):
    mat = mat.toarray()
bin_mat = (mat > 0).astype(int)
df_ind = pd.DataFrame(
    bin_mat,
    index=adata_filtered.obs_names,
    columns=[g for g in sgRNA_genes]
)
adata_filtered.obs = adata_filtered.obs.join(df_ind)

obs_clean = adata_filtered.obs.drop(columns=["total_counts"], errors="ignore")
gene_cols = [g for g in sgRNA_genes if g in obs_clean.columns]

counts = obs_clean[gene_cols].sum(axis=0).sort_values(ascending=False)
counts_df = pd.DataFrame({
    "gene":  counts.index,
    "count": counts.values
})
counts_df["rank"] = counts_df["count"].rank(ascending=False, method="dense")

top4 = counts_df.loc[:3, 'gene'].tolist()
remaining = [
    col for col in adata_filtered.obs.columns
    if col not in top4 + ['total_counts']
]
adata_filtered.obs['sgRNA_Gene_count'] = (
    adata_filtered.obs[remaining].sum(axis=1)
)
adata_filtered.obs['perturbation'] = np.where(
    adata_filtered.obs['sgRNA_Gene_count'] > 0,
    'perturbed',
    'unperturbed'
)
cell_perturb_ind = adata_filtered.obs.copy()[['sgRNA_Gene_count', 'perturbation']]

# %%
top4
# Out:
# ['ID2-4', 'SOX5-3', 'NFIB-2', 'ID2-2']

# %%
obs = adata_filtered.obs[remaining]  # a pandas.DataFrame, indexed by cell_id
sgRNA_cols = [col for col in obs.columns if "-" in col]

gene_names = sorted({col.split("-", 1)[0] for col in sgRNA_cols})
perturb_df = pd.DataFrame(index=obs.index, columns=gene_names, dtype="object")

for gene in gene_names:
    matching_cols = [col for col in sgRNA_cols if col.startswith(gene + "-")]
    if not matching_cols:
        continue

    sub_df = obs[matching_cols]
    any_positive = (sub_df > 0).any(axis=1)
    perturb_df[gene] = any_positive.map({True: "perturbed", False: "unperturbed"})
print("First few rows of perturb_df:")
print(perturb_df.iloc[:5, :5])  # show a small 5×5 corner
for gene in gene_names:
    colname = f"{gene}_perturb_status"
    adata_filtered.obs[colname] = perturb_df[gene]
# Out:
# First few rows of perturb_df:
#                    AFF1         BCL6         BNC2      CARHSP1        CREB5
# aaadneob-1  unperturbed  unperturbed  unperturbed  unperturbed  unperturbed
# aaahmode-1    perturbed  unperturbed  unperturbed  unperturbed  unperturbed
# aaahnoof-1  unperturbed  unperturbed  unperturbed  unperturbed  unperturbed
# aaajgnge-1  unperturbed  unperturbed  unperturbed  unperturbed  unperturbed
# aaaohebe-1  unperturbed  unperturbed  unperturbed  unperturbed  unperturbed

# %%
cell_list = ['boljjmgm-1', 'bolicola-1', 'chhohmfi-1', 'bolonabg-1',]

# %%
subset = perturb_df.loc[cell_list]

perturbed_per_cell = subset.apply(
    lambda row: row[row == "perturbed"].index.tolist(),
    axis=1
)

genes_perturbed_any = subset.columns[(subset == "perturbed").any()].tolist()
genes_perturbed_all = subset.columns[(subset == "perturbed").all()].tolist()

print("Perturbed genes per cell:")
print(perturbed_per_cell)

print("\nGenes perturbed in any of the four cells:")
print(genes_perturbed_any)

print("\nGenes perturbed in all four cells:")
print(genes_perturbed_all)
# Out:
# Perturbed genes per cell:
# boljjmgm-1            [HMGB2]
# bolicola-1          [ONECUT2]
# chhohmfi-1    [ISL1, ONECUT1]
# bolonabg-1             [ISL1]
# dtype: object
#
# Genes perturbed in any of the four cells:
# ['HMGB2', 'ISL1', 'ONECUT1', 'ONECUT2']
#
# Genes perturbed in all four cells:
# []
